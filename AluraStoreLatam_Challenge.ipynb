# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd
import matplotlib.pyplot as plt
url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda1 = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda1.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
lista_tiendas = [tienda1, tienda2, tienda3, tienda4]
tiendas_ventas_total = []
cont_tienda = 0

for tienda in lista_tiendas:
  cont_tienda += 1
  tiendas_ventas_total.append(tienda.Precio.sum())
  print(f'La facturación total de la tienda {cont_tienda}  es de {tienda.Precio.sum()}')
# Out:
# La facturación total de la tienda 1  es de 1150880400.0
# La facturación total de la tienda 2  es de 1116343500.0
# La facturación total de la tienda 3  es de 1098019600.0
# La facturación total de la tienda 4  es de 1038375700.0

# %%
tiendas = ['tienda1', 'tienda2', 'tienda3', 'tienda4']
plt.bar(tiendas, tiendas_ventas_total)
plt.xlabel('Tiendas')
plt.ylabel('Ventas')
plt.title('Ventas por tienda')
plt.show()

# %%
print(f'La tienda 1 es la que posee mas facturación con un total de {tienda1.Precio.sum()}')
print(f'La tienda 4 es la que posee menos facturación con un total de {tienda4.Precio.sum()}')
# Out:
# La tienda 1 es la que posee mas facturación con un total de 1150880400.0
# La tienda 4 es la que posee menos facturación con un total de 1038375700.0

# %% [markdown]
# # 2. Ventas por categoría

# %%
tiendas_combinadas = pd.concat([tienda1, tienda2, tienda3, tienda4])
categorias1 = tienda1['Categoría del Producto']
categorias2 = tienda2['Categoría del Producto']
categorias3 = tienda3['Categoría del Producto']
categorias4 = tienda4['Categoría del Producto']

# %%
categorias1.value_counts()
# Out:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64

# %%
categorias2.value_counts()
# Out:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64

# %%
categorias3.value_counts()
# Out:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# Artículos para el hogar    177
# Name: count, dtype: int64

# %%
categorias4.value_counts()
# Out:
# Categoría del Producto
# Muebles                    480
# Electrónicos               451
# Juguetes                   338
# Deportes y diversión       277
# Electrodomésticos          254
# Artículos para el hogar    201
# Libros                     187
# Instrumentos musicales     170
# Name: count, dtype: int64

# %%
plt.pie(categorias1.value_counts(), labels = categorias1.value_counts().index.tolist(), autopct='%1.1f%%')
plt.title('Ventas por categoria en tienda 1')
plt.show()

# %%
plt.pie(categorias2.value_counts(), labels = categorias2.value_counts().index.tolist(), autopct='%1.1f%%')
plt.title('Ventas por categoria en tienda 2')
plt.show()

# %%
plt.pie(categorias3.value_counts(), labels = categorias3.value_counts().index.tolist(), autopct='%1.1f%%')
plt.title('Ventas por categoria en tienda 3')
plt.show()

# %%
plt.pie(categorias4.value_counts(), labels = categorias4.value_counts().index.tolist(), autopct='%1.1f%%')
plt.title('Ventas por categoria en tienda 4')
plt.show()

# %%
categorias_vendidas = tiendas_combinadas['Categoría del Producto'].value_counts()
categoria_mas_vendida = tiendas_combinadas['Categoría del Producto'].value_counts().idxmax()
print(categorias_vendidas)
print(f'La categoria más vendida en general es {categoria_mas_vendida}')
# Out:
# Categoría del Producto
# Muebles                    1886
# Electrónicos               1772
# Juguetes                   1290
# Electrodomésticos          1149
# Deportes y diversión       1113
# Instrumentos musicales      753
# Libros                      742
# Artículos para el hogar     730
# Name: count, dtype: int64
# La categoria más vendida en general es Muebles

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
calificacion_general =  tiendas_combinadas['Calificación'].mean()
print(f'la calificacion general de las tiendas es de {round(calificacion_general,2)}%')
# Out:
# la calificacion general de las tiendas es de 4.01%

# %%
calificaciones_tiendas = [tienda['Calificación'].mean() for tienda in lista_tiendas]

for i in range (len(calificaciones_tiendas)):
  print(f'La calificacion de satisfacción de la tienda {i+1} es de {round(calificaciones_tiendas[i],3)}%')
# Out:
# La calificacion de satisfacción de la tienda 1 es de 3.977%
# La calificacion de satisfacción de la tienda 2 es de 4.037%
# La calificacion de satisfacción de la tienda 3 es de 4.048%
# La calificacion de satisfacción de la tienda 4 es de 3.996%

# %% [markdown]
# La tienda con menos satisfacción es la tienda 1 y siguiente de este, la tienda 4.

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
tiendas_combinadas['Producto'].value_counts()
# Out:
# Producto
# Mesa de noche                  210
# Carrito de control remoto      206
# Microondas                     206
# Batería                        203
# Cama king                      201
# Secadora de ropa               200
# Modelado predictivo            200
# Set de ollas                   200
# Cama box                       199
# Bloques de construcción        199
# Iphone 15                      198
# Armario                        197
# Pandereta                      197
# Balón de baloncesto            197
# Bicicleta                      196
# Iniciando en programación      195
# Smart TV                       192
# Refrigerador                   191
# Lavavajillas                   189
# Cubertería                     189
# Guitarra acústica              188
# Impresora                      188
# Kit de bancas                  188
# Vaso térmico                   187
# Estufa                         187
# TV LED UHD 4K                  187
# ...

# %%
producto_menos_vendido = tiendas_combinadas['Producto'].value_counts().idxmin()
print(f'El producto menos vendido es {producto_menos_vendido}')
producto_mas_vendido = tiendas_combinadas['Producto'].value_counts().idxmax()
print(f'El producto más vendido es {producto_mas_vendido}')
# Out:
# El producto menos vendido es Celular ABXY
# El producto más vendido es Mesa de noche

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
promedios_tiendas = [tienda['Costo de envío'].mean() for tienda in lista_tiendas]

for i in range (len(promedios_tiendas)):
  print(f'El costo de envío promedio de la tienda {i+1} es de {round(promedios_tiendas[i],2)}')
# Out:
# El costo de envío promedio de la tienda 1 es de 26018.61
# El costo de envío promedio de la tienda 2 es de 25216.24
# El costo de envío promedio de la tienda 3 es de 24805.68
# El costo de envío promedio de la tienda 4 es de 23459.46

# %%
plt.bar(tiendas, promedios_tiendas)
plt.xlabel('Tiendas')
plt.ylabel('Costo de envío promedio')
plt.title('Costo de envío promedio por tienda')
plt.show()

# %% [markdown]
# ***Informe final***
#
# ***Introducción***
#
# El análisis se ha llevado a cabo para observar el desempeño de las tiendas, su comportamiento, haciendo enfasis en sus puntos fuertes y sus puntos debiles, con el fin de conocer que tienda es la más apta para vender.
# Los elementos principales a analizar seran el total de facturación por tienda, su promedio de calificación y el costo promedio del envío de estos.
#
# ***Desarrollo***
#
# 1.   Facturación por tienda:
# Empezando por el total que factura cada tienda, el siguiente gráfico nos muestra el comportamiento que tiene cada tienda.
#
# ![image.png](data:image/png;base64,...)
#
# Podemos observar que la tienda 1 es la que más factura con respecto a las otras tiendas, además la que menos factura es la tienda 4 con una relevante diferencia con respeto a la primera.
#
# 2. Promedio de calificación:
#
# La calificación de satisfacción del cliente se muestran a continuación:
#
# tienda 1 : 3.977%
#
# tienda 2 : 4.037%
#
# tienda 3 : 4.048%
#
# tienda 4 : 3.996%
#
# La satisfacción del cliente es similar en todas las tiendas, donde aproximadamente es 4, pero ciertamente, la información brinda que la que más satisfacción tiene es la tienda 3, mientras que la que menos satisfacción ofrece es la tienda 1, seguido de la tienda 4, que no presentan mucha diferencia con respecto al valor.
#
# 3. Costo de envío promedio:
#
# En el costo de envío promedio de cada tienda, tenemos los siguientes resultados:
#
# ![image.png](data:image/png;base64,...)
#
# La gráfica anterior nos da información sobre que la tienda 1 es la que mayor coste de envío promedio presenta, mientras que la tienda 4, es la que menos coste de envío promedio tiene.
#
# ***Conclusión***
#
# De acuerdo a lo abordado con anterioridad, la tienda que se deberia vender es la 4, esto es dado a que tiene la menor facturación entre las tiendas presentadas, es de las tiendas que menos satisfacción al cliente tiene, que aunque la tienda 1 es la que menos tenga, la diferencia no es significativa, además hay que tomar en cuenta que es la que más factura. Tomando otro punto que es el coste de envío, aunque la tienda 1 es la que más coste presenta, este sigue presentando buenas ganancias, por otro lado la tienda 4 es la que presenta menos coste de envío, sin embargo, este no es suficiente y sigue siendo el que menos ingresos da entre las cuatro tiendas tomando la cantidad de productos vendidos.
